# %% [markdown]
# # **IMPORT LIBRARIES**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **READ THE DATASET**

# %%
data = pd.read_csv("/content/Flipkart_Mobiles.csv")

# %% [markdown]
# # **EXPLORE THE DATA**

# %%
data.head()
# Out:
#   Brand Model            Color Memory Storage  Rating  Selling Price  \
# 0  OPPO   A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1  OPPO   A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2  OPPO   A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3  OPPO   A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4  OPPO   A53   Electric Black   4 GB   64 GB     4.5          11990
#
#    Original Price
# 0           15990
# 1           15990
# 2           17990
# 3           17990
# 4           15990

# %%
data.columns
# Out:
# Index(['Brand', 'Model', 'Color', 'Memory', 'Storage', 'Rating',
#        'Selling Price', 'Original Price'],
#       dtype='object')

# %%
data.shape
# Out:
# (3114, 8)

# %%
data.describe()
# Out:
#             Rating  Selling Price  Original Price
# count  2970.000000    3114.000000     3114.000000
# mean      4.243098   26436.625562    28333.473025
# std       0.271991   30066.892622    31525.599889
# min       2.300000    1000.000000     1000.000000
# 25%       4.100000    9990.000000    10030.250000
# 50%       4.300000   15000.000000    16889.500000
# 75%       4.400000   28999.000000    31500.000000
# max       5.000000  179900.000000   189999.000000

# %%
data.dtypes
# Out:
# Brand              object
# Model              object
# Color              object
# Memory             object
# Storage            object
# Rating            float64
# Selling Price       int64
# Original Price      int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Brand               0
# Model               0
# Color               0
# Memory             43
# Storage            39
# Rating            144
# Selling Price       0
# Original Price      0
# dtype: int64

# %%
ra = np.floor(data['Rating'].mean())

# %%
from scipy.stats import mode

# %%
me = '4 GB'

# %%
sto = '64 GB'

# %%
data['Rating'].fillna(value = ra , inplace = True)

# %%
data['Memory'].fillna(value = me , inplace = True)

# %%
data['Storage'].fillna(value = sto , inplace = True)

# %%
data.isnull().sum()
# Out:
# Brand             0
# Model             0
# Color             0
# Memory            0
# Storage           0
# Rating            0
# Selling Price     0
# Original Price    0
# dtype: int64

# %%
data.dtypes
# Out:
# Brand              object
# Model              object
# Color              object
# Memory             object
# Storage            object
# Rating            float64
# Selling Price       int64
# Original Price      int64
# dtype: object

# %%
max_op = max(data['Original Price'])

# %%
data[data['Original Price']==max_op]
# Out:
#         Brand           Model          Color Memory Storage  Rating  \
# 1685  SAMSUNG  Galaxy Fold 2   Mystic Bronze  12 GB  256 GB     3.0
# 1784  SAMSUNG  Galaxy Fold 2    Mystic Black  12 GB  256 GB     3.0
#
#       Selling Price  Original Price
# 1685         149999          189999
# 1784         149999          189999

# %%
min_op = min(data['Original Price'])

# %%
data[data['Original Price']==min_op]
# Out:
#      Brand         Model  Color Memory Storage  Rating  Selling Price  \
# 987  Nokia  Ta -1010/105  Black   4 MB    4 MB     4.2           1000
# 988  Nokia           105  Black   4 MB    4 MB     4.3           1000
#
#      Original Price
# 987            1000
# 988            1000

# %%
max_sp = max(data['Selling Price'])

# %%
data[data['Selling Price']==max_sp]
# Out:
#       Brand               Model        Color Memory Storage  Rating  \
# 1233  Apple  iPhone 13 Pro Max   Sierra Blue   6 GB    1 TB     4.0
# 1255  Apple  iPhone 13 Pro Max          Gold   6 GB   64 GB     4.0
# 1351  Apple  iPhone 13 Pro Max          Gold   6 GB    1 TB     4.0
# 1414  Apple  iPhone 13 Pro Max      Graphite   6 GB    1 TB     4.0
# 1459  Apple  iPhone 13 Pro Max        Silver   6 GB    1 TB     4.0
# 3044  Apple   iPhone 13 Pro Max       Silver    4GB    1 TB     4.7
# 3051  Apple   iPhone 13 Pro Max         Gold    4GB    1 TB     4.7
# 3057  Apple   iPhone 13 Pro Max     Graphite    4GB    1 TB     4.7
# 3058  Apple   iPhone 13 Pro Max  Sierra Blue    4GB    1 TB     4.7
#
#       Selling Price  Original Price
# 1233         179900          179900
# 1255         179900          179900
# 1351         179900          179900
# 1414         179900          179900
# 1459         179900          179900
# 3044         179900          179900
# ...

# %%
min_sp = min(data['Selling Price'])

# %%
data[data['Selling Price']==min_sp]
# Out:
#      Brand         Model  Color Memory Storage  Rating  Selling Price  \
# 987  Nokia  Ta -1010/105  Black   4 MB    4 MB     4.2           1000
# 988  Nokia           105  Black   4 MB    4 MB     4.3           1000
#
#      Original Price
# 987            1000
# 988            1000

# %%
max_rat = max(data['Rating'])

# %%
data[data['Rating']==max_rat]
# Out:
#         Brand           Model           Color  Memory Storage  Rating  \
# 1252    Apple  iPhone 7 Plus              Red    3 GB  256 GB     5.0
# 1348    Apple  iPhone 7 Plus              Red    3 GB  256 GB     5.0
# 2021  SAMSUNG  SM-B310EZDDINS           Black  100 MB  100 MB     5.0
# 2789     vivo         X60 Pro    Shimmer Blue   12 GB  256 GB     5.0
# 2791     vivo           X50        Frost Blue    8 GB  256 GB     5.0
# 2797     vivo             Z1x  Phantom Purple    6 GB   64 GB     5.0
# 2799     vivo              S2   Diamond Black    4 GB  128 GB     5.0
#
#       Selling Price  Original Price
# 1252          85400           85400
# 1348          85400           85400
# 2021           1949            1949
# 2789          48780           48780
# 2791          44990           44990
# 2797          19990           19990
# 2799          19990           19990

# %%
min_rat = min(data['Rating'])

# %%
data[data['Rating']==min_rat]
# Out:
#        Brand          Model        Color Memory Storage  Rating  \
# 2619  Xiaomi  Redmi Note 8   Space Black   4 GB   64 GB     2.3
#
#       Selling Price  Original Price
# 2619          11999           11999

# %% [markdown]
# # **CORRELATION**

# %%
sns.heatmap(data.corr() , annot = True , linewidths = 1 , fmt = ".2f")
# Out:
# <ipython-input-33-90b79d9865e6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr() , annot = True , linewidths = 1 , fmt = ".2f")
# <Axes: >

# %% [markdown]
# Rating column is +ve correlated with Selling Price
#
# and Original Price column
#
#
#
# ---
#
#
#
# Selling Price column is +ve correlated with selling
#
# price column
